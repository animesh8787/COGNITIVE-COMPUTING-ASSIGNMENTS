# %%
import nltk

# %%
#Q1. Write a unique paragraph (5-6 sentences) about your favorite topic (e.g., sports, technology, food, books, etc.).

#Convert text to lowercase and remove punctuation.
#Tokenize the text into words and sentences.
#Remove stopwords (using NLTK's stopwords list).
#Display word frequency distribution (excluding stopwords).

text="Cricket is more than just a sport; it's a passion for millions around the world. Whether it's a local match or an international tournament, the excitement and energy are unmatched. I love watching close games that go down to the last over, keeping everyone on the edge of their seats. From legendary players to rising stars, cricket is full of thrilling stories and unforgettable moments. Playing cricket with friends in the park is always a great way to bond and stay active. The sound of the ball hitting the bat is pure joy for any cricket lover."
print(text)
# Out:
# Cricket is more than just a sport; it's a passion for millions around the world. Whether it's a local match or an international tournament, the excitement and energy are unmatched. I love watching close games that go down to the last over, keeping everyone on the edge of their seats. From legendary players to rising stars, cricket is full of thrilling stories and unforgettable moments. Playing cricket with friends in the park is always a great way to bond and stay active. The sound of the ball hitting the bat is pure joy for any cricket lover.

# %%
import re
text=re.sub(r"[^\w\s.]", " ", text.lower())
print(text)
# Out:
# cricket is more than just a sport  it s a passion for millions around the world. whether it s a local match or an international tournament  the excitement and energy are unmatched. i love watching close games that go down to the last over  keeping everyone on the edge of their seats. from legendary players to rising stars  cricket is full of thrilling stories and unforgettable moments. playing cricket with friends in the park is always a great way to bond and stay active. the sound of the ball hitting the bat is pure joy for any cricket lover.

# %%
import nltk
nltk.download('punkt_tab')
from nltk.tokenize import word_tokenize
word_tokens=word_tokenize(text)
print(word_tokens)
# Out:
# [nltk_data] Downloading package punkt_tab to
# [nltk_data]     C:\Users\anime\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping tokenizers\punkt_tab.zip.
# ...

# %%
from nltk.tokenize import sent_tokenize
sent_tokens=sent_tokenize(text)
print(sent_tokens)
# Out:
# ['cricket is more than just a sport  it s a passion for millions around the world.', 'whether it s a local match or an international tournament  the excitement and energy are unmatched.', 'i love watching close games that go down to the last over  keeping everyone on the edge of their seats.', 'from legendary players to rising stars  cricket is full of thrilling stories and unforgettable moments.', 'playing cricket with friends in the park is always a great way to bond and stay active.', 'the sound of the ball hitting the bat is pure joy for any cricket lover.']

# %%
import nltk
nltk.download('stopwords')
from nltk.corpus import stopwords
stop_words=set(stopwords.words("english"))

filtered_tokens=[word for word in word_tokens if word.lower() not in stop_words]
s= ' '.join(filtered_tokens)
print(s)
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\anime\AppData\Roaming\nltk_data...
# cricket sport passion millions around world . whether local match international tournament excitement energy unmatched . love watching close games go last keeping everyone edge seats . legendary players rising stars cricket full thrilling stories unforgettable moments . playing cricket friends park always great way bond stay active . sound ball hitting bat pure joy cricket lover .
# [nltk_data]   Unzipping corpora\stopwords.zip.

# %%
from nltk.probability import FreqDist
freq_dist=FreqDist(filtered_tokens)

for word, freq in freq_dist.most_common(10):
    print(f"{word}: {freq}")

freq_dist.plot(10, title="Word Frequency (Excluding Stopwords)")
# Out:
# .: 6
# cricket: 4
# sport: 1
# passion: 1
# millions: 1
# around: 1
# world: 1
# whether: 1
# local: 1
# match: 1
# <Axes: title={'center': 'Word Frequency (Excluding Stopwords)'}, xlabel='Samples', ylabel='Counts'>

# %%
#Q2: Stemming and Lemmatization

#Take the tokenized words from Question 1 (after stopword removal).
#Apply stemming using NLTK's PorterStemmer and LancasterStemmer.
#Apply lemmatization using NLTK's WordNetLemmatizer.
#Compare and display results of both techniques.

from nltk.stem import PorterStemmer,LancasterStemmer
ps=PorterStemmer()
ls=LancasterStemmer()

porter_stems=[ps.stem(word) for word in filtered_tokens]
lancaster_stems=[ls.stem(word) for word in filtered_tokens]

# %%
import nltk
nltk.download('wordnet')
from nltk.stem import WordNetLemmatizer
lemmatizer=WordNetLemmatizer()
lemmatized_words=[lemmatizer.lemmatize(word) for word in filtered_tokens]
# Out:
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\anime\AppData\Roaming\nltk_data...

# %%
print(f"{'Original':<15}{'PorterStemmer':<20}{'LancasterStemmer':<20}{'Lemmatizer'}")
print("-" * 75)
for original, ps, ls, lm in zip(filtered_tokens, porter_stems, lancaster_stems, lemmatized_words):
    print(f"{original:<15}{ps:<20}{ls:<20}{lm}")
# Out:
# Original       PorterStemmer       LancasterStemmer    Lemmatizer
# ---------------------------------------------------------------------------
# cricket        cricket             cricket             cricket
# sport          sport               sport               sport
# passion        passion             pass                passion
# millions       million             mil                 million
# around         around              around              around
# world          world               world               world
# .              .                   .                   .
# whether        whether             wheth               whether
# local          local               loc                 local
# match          match               match               match
# international  intern              intern              international
# tournament     tournament          tourna              tournament
# excitement     excit               excit               excitement
# ...

# %%
#Q3. Regular Expressions and Text Splitting

#1.Take their original text from Ques on 1.

#2.Use regular expressions to:

#a. Extract all words with more than 5 letters.

#b. Extract all numbers (if any exist in their text).

#c. Extract all capitalized words.

#3.Use text splitting techniques to:

#a. Split the text into words containing only alphabets (removing digits and special characters).

#b. Extract words starting with a vowel.

text="Cricket is more than just a sport; it's a passion for millions around the world. Whether it's a local match or an international tournament, the excitement and energy are unmatched. I love watching close games that go down to the last over, keeping everyone on the edge of their seats. From legendary players to rising stars, cricket is full of thrilling stories and unforgettable moments. Playing cricket with friends in the park is always a great way to bond and stay active. The sound of the ball hitting the bat is pure joy for any cricket lover."
print(text)
# Out:
# Cricket is more than just a sport; it's a passion for millions around the world. Whether it's a local match or an international tournament, the excitement and energy are unmatched. I love watching close games that go down to the last over, keeping everyone on the edge of their seats. From legendary players to rising stars, cricket is full of thrilling stories and unforgettable moments. Playing cricket with friends in the park is always a great way to bond and stay active. The sound of the ball hitting the bat is pure joy for any cricket lover.

# %%
word_5=re.findall(r'\b[a-zA-Z]{6,}\b',text)
print(word_5)
# Out:
# ['Cricket', 'passion', 'millions', 'around', 'Whether', 'international', 'tournament', 'excitement', 'energy', 'unmatched', 'watching', 'keeping', 'everyone', 'legendary', 'players', 'rising', 'cricket', 'thrilling', 'stories', 'unforgettable', 'moments', 'Playing', 'cricket', 'friends', 'always', 'active', 'hitting', 'cricket']

# %%
all_numbers=re.findall(r'\b\d+\b',text)
print(all_numbers)
# Out:
# []

# %%
capt_words=re.findall(r'\b[A-Z][a-z]*\b',text)
print(capt_words)
# Out:
# ['Cricket', 'Whether', 'I', 'From', 'Playing', 'The']

# %%
alphabets=re.findall(r'\b[a-zA-Z]+\b',text)
print(alphabets)
# Out:
# ['Cricket', 'is', 'more', 'than', 'just', 'a', 'sport', 'it', 's', 'a', 'passion', 'for', 'millions', 'around', 'the', 'world', 'Whether', 'it', 's', 'a', 'local', 'match', 'or', 'an', 'international', 'tournament', 'the', 'excitement', 'and', 'energy', 'are', 'unmatched', 'I', 'love', 'watching', 'close', 'games', 'that', 'go', 'down', 'to', 'the', 'last', 'over', 'keeping', 'everyone', 'on', 'the', 'edge', 'of', 'their', 'seats', 'From', 'legendary', 'players', 'to', 'rising', 'stars', 'cricket', 'is', 'full', 'of', 'thrilling', 'stories', 'and', 'unforgettable', 'moments', 'Playing', 'cricket', 'with', 'friends', 'in', 'the', 'park', 'is', 'always', 'a', 'great', 'way', 'to', 'bond', 'and', 'stay', 'active', 'The', 'sound', 'of', 'the', 'ball', 'hitting', 'the', 'bat', 'is', 'pure', 'joy', 'for', 'any', 'cricket', 'lover']

# %%
vowel_words=[word for word in alphabets if re.match(r'^[aeiouAEIOU]',word)]
print(vowel_words)
# Out:
# ['is', 'a', 'it', 'a', 'around', 'it', 'a', 'or', 'an', 'international', 'excitement', 'and', 'energy', 'are', 'unmatched', 'I', 'over', 'everyone', 'on', 'edge', 'of', 'is', 'of', 'and', 'unforgettable', 'in', 'is', 'always', 'a', 'and', 'active', 'of', 'is', 'any']

# %%
#Q4. Custom Tokenization & Regex-based Text Cleaning

#1.Take original text from Ques on 1.

#2.Write a custom tokenization function that:

#a. Removes punctuation and special symbols, but keeps contractions (e.g., "isn't" should not be split into "is" and "n't").

#b. Handles hyphenated words as a single token (e.g., "state-of-the-art" remains a single token).

#c. Tokenizes numbers separately but keeps decimal numbers intact (e.g., "3.14" should remain as is).

#3.Use Regex Substitutions (re.sub) to:

#a. Replace email addresses with EMAIL placeholder.

#b. Replace URLs with URL placeholder.

#c. Replace phone numbers (formats: 123-456-7890 or +91 9876543210) with PHONE placeholder.

text="Cricket is more than just a sport; it's a passion for millions around the world. Whether it's a local match or an international tournament, the excitement and energy are unmatched. I love watching close games that go down to the last over, keeping everyone on the edge of their seats. From legendary players to rising stars, cricket is full of thrilling stories and unforgettable moments. Playing cricket with friends in the park is always a great way to bond and stay active. The sound of the ball hitting the bat is pure joy for any cricket lover."
print(text)
# Out:
# Cricket is more than just a sport; it's a passion for millions around the world. Whether it's a local match or an international tournament, the excitement and energy are unmatched. I love watching close games that go down to the last over, keeping everyone on the edge of their seats. From legendary players to rising stars, cricket is full of thrilling stories and unforgettable moments. Playing cricket with friends in the park is always a great way to bond and stay active. The sound of the ball hitting the bat is pure joy for any cricket lover.

# %%
def custom_tokenize(text):
    text = re.sub(r"[–—]", "-", text)
    clean_text = re.sub(r"[^\w\s'-]", '', text)
    tokens = re.findall(r"\b(?:\d+\.\d+|\w+(?:[-']\w+)*)\b", clean_text)
    return tokens
tokens=custom_tokenize(text)
print(tokens)
# Out:
# ['Cricket', 'is', 'more', 'than', 'just', 'a', 'sport', "it's", 'a', 'passion', 'for', 'millions', 'around', 'the', 'world', 'Whether', "it's", 'a', 'local', 'match', 'or', 'an', 'international', 'tournament', 'the', 'excitement', 'and', 'energy', 'are', 'unmatched', 'I', 'love', 'watching', 'close', 'games', 'that', 'go', 'down', 'to', 'the', 'last', 'over', 'keeping', 'everyone', 'on', 'the', 'edge', 'of', 'their', 'seats', 'From', 'legendary', 'players', 'to', 'rising', 'stars', 'cricket', 'is', 'full', 'of', 'thrilling', 'stories', 'and', 'unforgettable', 'moments', 'Playing', 'cricket', 'with', 'friends', 'in', 'the', 'park', 'is', 'always', 'a', 'great', 'way', 'to', 'bond', 'and', 'stay', 'active', 'The', 'sound', 'of', 'the', 'ball', 'hitting', 'the', 'bat', 'is', 'pure', 'joy', 'for', 'any', 'cricket', 'lover']

# %%
def replace_sensitive_info(text):
    text = re.sub(r'\b[\w\.-]+@[\w\.-]+\.\w+\b', 'EMAIL', text)
    text = re.sub(r'https?://\S+', 'URL', text)
    text = re.sub(r'(\+\d{1,3}\s\d{10})|(\d{3}-\d{3}-\d{4})', 'PHONE', text)
    return text

# %%
text = """Feel free to reach out to me at john.doe@newdomain.com or check out my website at https://updatedsite.com.
Alternatively, you can reach me by phone at +44 7896543210 or 987-654-3210.
Another way to contact me is via my email: user_example123@newmail.org"""
print(text)
# Out:
# Feel free to reach out to me at john.doe@newdomain.com or check out my website at https://updatedsite.com.
# Alternatively, you can reach me by phone at +44 7896543210 or 987-654-3210.
# Another way to contact me is via my email: user_example123@newmail.org

# %%
print(replace_sensitive_info(text))
# Out:
# Feel free to reach out to me at EMAIL or check out my website at URL
# Alternatively, you can reach me by phone at PHONE or PHONE.
# Another way to contact me is via my email: EMAIL
